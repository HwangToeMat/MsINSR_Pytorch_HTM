# %%
from google.colab import drive
import os
drive.mount('/content/gdrive')
os.chdir('/content/gdrive/My Drive/MsINSR_Pytorch_HTM')
_path = os.getcwd()
_path
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
# '/content/gdrive/My Drive/MsINSR_Pytorch_HTM'

# %% [markdown]
# # Train

# %% [markdown]
# 적응형 가중치 7블록

# %%
# !python main.py --cuda --pretrained '/content/gdrive/My Drive/MsINSR_Pytorch_HTM/checkpoint/MsINSR_Adam_epoch_11.tar'
# Out:
# Namespace(Gen_parm=0, L1_parm=1.0, Percept_parm=0, TV_parm=2e-08, batchSize=64, cuda=True, datapath='data/train_pre_x4.h5', gpus='0', nEpochs=100, pretrained='/content/gdrive/My Drive/MsINSR_Pytorch_HTM/checkpoint/MsINSR_Adam_epoch_11.tar', threads=4)
# ===> Setting GPU
# => use gpu id: '0'
# Random Seed:  2572
# ===> Loading datasets
# ===> Building model
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/checkpoints/vgg16-397923af.pth
# 100% 528M/528M [00:06<00:00, 86.9MB/s]
# => loading model '/content/gdrive/My Drive/MsINSR_Pytorch_HTM/checkpoint/MsINSR_Adam_epoch_11.tar'
# ===> Setting Optimizer
# ===> Setting Pretrained Optimizer
# => start epoch '12'
# ===> Training
# ===>  Start epoch 12 #################################################################
# ===> Epoch[[12](0/1875)]: D_Loss : 0.0000056782, G_Loss : 0.0607367791, SSIM : 0.8588953018
# ...
